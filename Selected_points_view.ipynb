# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from scipy.io import loadmat
from ntpath import join

# %%
name='ZM004_b'
data=loadmat(join(r'C:\Users\kuba8\MATLAB Drive\projekt oblicej\datapropouziti',name,name+'_coordinates',name+'_coordinates_'+str(8)))
df=pd.DataFrame(data['model'].transpose())
data=loadmat(join(r'C:\Users\kuba8\MATLAB Drive\projekt oblicej\datapropouziti',name,name+'_coordinates',name+'_coordinates_'+str(50)))
df0=pd.DataFrame(data['model'].transpose())

# %%
df
# Out:
#              0         1         2
# 0    -0.085178 -0.047977  0.681294
# 1    -0.085175 -0.046601  0.674425
# 2    -0.084943 -0.043498  0.658104
# 3    -0.084863 -0.039556  0.647731
# 4    -0.085160 -0.030353  0.640392
# ...        ...       ...       ...
# 1342 -0.063056  0.005821  0.641321
# 1343 -0.062790  0.004696  0.642255
# 1344 -0.062317  0.007013  0.642497
# 1345 -0.061909  0.006837  0.640552
# 1346 -0.061042  0.007285  0.639685
#
# [1347 rows x 3 columns]

# %%
stred = [28]#np.array([1072,1077,1076,1098,1099,1116,1117,1118,1122,1123,1124,1140,1141,1142,1143])

# %%
# Provide 'Address' as the column name
size = df.shape[0]
info = ["other" for x in range(size)]
df['info'] = info

for i in stred:
  df.loc[i,"info"]="center"

size = df.shape[0]
info = [0 for x in range(size)]
df['marker'] = info

for i in range((size)):
  df.loc[i,"marker"]=i

# %%
size = df0.shape[0]
info = ["other" for x in range(size)]
df0['info'] = info

for i in stred:
  df0.loc[i,"info"]="center"

size = df0.shape[0]
info = [0 for x in range(size)]
df0['marker'] = info

for i in range((size)):
  df0.loc[i,"marker"]=i

# %%
points=pd.read_csv(r'C:\Users\kuba8\Desktop\studium\points_informationA.csv',sep=';')
size = df.shape[0]
info = ["other" for x in range(size)]
df['info'] = info

for i in points['index_1']:
  df.loc[i,"info"]="center"

# %%
# Provide 'Address' as the column name
size = df0.shape[0]
info = ["other" for x in range(size)]
df0['info'] = info

for i in ['index_1']:
  df0.loc[i,"info"]="center"

# %%
sns.set(style = "darkgrid")

fig = plt.figure(figsize=(16, 12), dpi=80)
ax = fig.add_subplot(111, projection = '3d')


names = pd.unique(df['info'])

df1=df[df['info'] == 'other']

x = df1[0]
y = df1[1]
z = df1[2]

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")


ax.scatter(x, y, z)

dfA=df[df['info'] == 'center']

x = dfA[0]
y = dfA[1]
z = dfA[2]

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.scatter(x, y, z, color = "red",s=100)

ax.view_init(-90, 90)

plt.show()

# %%
plt.scatter(df[0],df[1],df[2])
a=18
plt.scatter(df[0][a],df[1][a],df[2][a],color='red')
plt.show()
